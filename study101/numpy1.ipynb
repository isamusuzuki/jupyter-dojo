# %% [markdown]
# ### Numpyで乱数を生成する
#
# numpy.random.random() メソッドを使う

# %%
from matplotlib import pyplot as plt
import numpy as np

random_list = np.random.random(size=1000)
plt.hist(random_list, bins=100)
plt.show()

# %% [markdown]
# numpy.random.randh() メソッドで、「平均0、標準偏差0」になるように乱数を生成する

# %%
random_list = np.random.randn(1000)
plt.hist(random_list, bins=100)
plt.show()
