# %% [markdown]
# ### いろいろな図を作成する

# %%
import matplotlib.pyplot as plt
import numpy as np

# サンプルコード1号
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x,y)

# %%
# sin関数を2次元平面に描画する
x = np.arange(-3, 3, 0.1)
y = np.sin(x)
plt.plot(x,y)

# %%
# 散布図
x = np.random.randn(30)
y = np.sin(x) + np.random.randn(30)
plt.plot(x,y,'ro')
# 'o' ... 小さい円
# 'ro' ... 赤い円

# %%
# 正規分布に従う乱数をヒストグラムで描画
plt.hist(np.random.randn(100))
# Out:
# (array([ 2.,  9., 15., 16., 23., 13., 13.,  2.,  5.,  2.]),
#  array([-2.59500076, -1.99284646, -1.39069216, -0.78853786, -0.18638356,
#          0.41577074,  1.01792504,  1.62007935,  2.22223365,  2.82438795,
#          3.42654225]),
#  <BarContainer object of 10 artists>)

# %%
# 2次元の巨大な100x100行列を画像として可視化
plt.imshow(np.random.randn(100, 100))
plt.title('100x100 matrix')
# Out:
# Text(0.5, 1.0, '100x100 matrix')

# %%
# y軸の表示幅を変更
x = np.arange(0, 10, 0.1)
y = np.exp(x)
plt.plot(x, y)
plt.title('exponential function: $ y = e^x $')
plt.ylim(0, 5000)
# Out:
# (0.0, 5000.0)
